# %%
import pandas as pd

# %%
agmd=pd.read_table("../data/ag_all_plus_mm_missing.txt", dtype=str, sep='\t', index_col=0)
agmd.head(5)
# Out:
#                 acid_reflux acne_medication acne_medication_otc  \
# 10317.000027826     no_data           false                true
# 10317.000027827     no_data           false               false
# 10317.000027825     no_data           false               false
# 10317.000014400     no_data            true                true
# 10317.000027820     no_data           false               false
#
#                                      add_adhd age_cat age_corrected age_years  \
# 10317.000027826  I do not have this condition     30s          35.0      35.0
# 10317.000027827  I do not have this condition     70+          77.0      77.0
# 10317.000027825  I do not have this condition     30s          31.0      31.0
# 10317.000014400                       Unknown     50s          50.0      50.0
# 10317.000027820  I do not have this condition     30s          33.0      33.0
#
#                 alcohol_consumption              alcohol_frequency  \
# ...

# %%
mmmd=pd.read_table("../data/ag235_w_scores.txt", dtype=str, sep='\t')
mmmd=mmmd.set_index("index")

# %%
for sample in agmd.index:
    if sample in mmmd.index:
        agmd.ix[sample,"mm_bool"]="MnM cohort"
    else:
        agmd.ix[sample,"mm_bool"]="Not MnM cohort"

# %%
agmd.groupby("mm_bool").count()
# Out:
#                 acid_reflux  acne_medication  acne_medication_otc  add_adhd  \
# mm_bool
# MnM cohort              235              235                  235       235
# Not MnM cohort        11062            11071                11071     11071
#
#                 age_cat  age_corrected  age_years  alcohol_consumption  \
# mm_bool
# MnM cohort          235            235        235                  235
# Not MnM cohort    11071          11071      11071                11071
#
#                 alcohol_frequency  alcohol_types_beercider  \
# mm_bool
# MnM cohort                    235                      235
# Not MnM cohort              11071                    11071
#
#                         ...            vioscreen_xylitol  vioscreen_zinc  \
# mm_bool                 ...
# MnM cohort              ...                          235             235
# Not MnM cohort          ...                        11062           11062
#
#                 vitamin_b_supplement_frequency  \
# ...

# %%
agmd.to_csv("../data/ag_all_plus_mm_missing_mmbool.txt",sep='\t')
