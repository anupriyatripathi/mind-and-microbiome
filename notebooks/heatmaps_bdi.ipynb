# %%
# %matplotlib notebook
import sys
sys.path.append('/Users/priya/Desktop/heatsequer')
import heatsequer as hs
import csv
import numpy as np

# %%
mm=hs.load('/Users/priya/Desktop/Knight-Dorrestein/mnm/Phase3/otu_nontrim_mnm_207_f.biom', '/Users/priya/Desktop/Knight-Dorrestein/mnm/Phase3/mm_md_207_w_alpha.txt')
# Out:
# ('Loading biom table /Users/priya/Desktop/Knight-Dorrestein/mnm/Phase3/otu_nontrim_mnm_207_f.biom',)
# 94503544973980e3ad0f02cbeac22c08
# ('Loading mapping file /Users/priya/Desktop/Knight-Dorrestein/mnm/Phase3/mm_md_207_w_alpha.txt',)
# ('number of samples in map is 207',)
# ('number of samples in table is 207',)
# ('removing 0 samples',)
# ('deleted. number of samples in table is now 207',)
# ('number of samples in mapping file is now 207',)

# %%
#sort by age
mm=hs.sortsamples(mm,'bin_bdi21_score',numeric=True)

# %%
mmc=hs.clusterbacteria(mm,10)
# Out:
# ('1964 Bacteria left',)

# %%
hs.plotexp(mmc,'bin_bdi21_score')
# Out:
# ('1964 Bacteria left',)
# <img src="data:image/png;base64,...">
# /Users/priya/anaconda2/envs/heatsequer/lib/python3.5/site-packages/matplotlib/artist.py:221: MatplotlibDeprecationWarning: This has been deprecated in mpl 1.5, please use the
# axes property.  A removal date has not been set.
#   warnings.warn(_get_axes_msg, mplDeprecation, stacklevel=1)
# (<heatsequer.experiment.expclass.Experiment at 0x12160ff28>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x12711be10>)

# %%
#getting differentially abundant bacteriaq
dd=hs.getdiffsig(mm,'bin_bdi21_score','1','4','ranksum')
# Out:
# ('177 Samples left',)
# ('4 Samples left',)
# /Users/priya/Desktop/heatsequer/heatsequer/utils/amnonutils.py:323: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   new_pvalues = np.empty(n)
# ('method ranksum. number of higher in 1 : 0. number of higher in 4 : 0. total 0',)

# %%
dd=hs.getpfdr(mm,'bin_bdi21_score','1',['3','4'],'ranksum',maxfval=0.25)
# Out:
# ('177 Samples left',)
# ('16 Samples left',)
# (3729, 193)
# permuting
# ok
# float64
# float64
# calculating fdr
# fixing floating point errors
# rank transforming
# fdring
# ok
# not low enough. number of rejects : 0
# ("method ranksum. number of higher in 1 : 0. number of higher in ['3', '4'] : 0. total 0",)

# %% [markdown]
# # Look at borderline heatmaps

# %%
mmb=hs.load('/Users/priya/Desktop/Knight-Dorrestein/mnm/Phase3/mnm_borderlinecases_bdi.biom','/Users/priya/Desktop/Knight-Dorrestein/mnm/Phase3/mnm_borderlinecases_bdi.txt')
# Out:
# ('Loading biom table /Users/priya/Desktop/Knight-Dorrestein/mnm/Phase3/mnm_borderlinecases_bdi.biom',)
# bc9dafc4334ecc59b714a1c1ba746f04
# ('Loading mapping file /Users/priya/Desktop/Knight-Dorrestein/mnm/Phase3/mnm_borderlinecases_bdi.txt',)
# ('number of samples in map is 32',)
# ('number of samples in table is 32',)
# ('removing 0 samples',)
# ('deleted. number of samples in table is now 32',)
# ('number of samples in mapping file is now 32',)

# %%
mmbc=hs.clusterbacteria(mmb,10)
# Out:
# ('908 Bacteria left',)

# %%
hs.plotexp(mmbc,'depression_level')
# Out:
# ('908 Bacteria left',)
# <img src="data:image/png;base64,...">
# /Users/priya/anaconda2/envs/heatsequer/lib/python3.5/site-packages/matplotlib/artist.py:221: MatplotlibDeprecationWarning: This has been deprecated in mpl 1.5, please use the
# axes property.  A removal date has not been set.
#   warnings.warn(_get_axes_msg, mplDeprecation, stacklevel=1)
# (<heatsequer.experiment.expclass.Experiment at 0x121785940>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x121fb01d0>)

# %%
dd=hs.getdiffsig(mmbc,'depression_level', 'normal')
# Out:
# ('16 Samples left',)
# ('16 Samples left',)
# ('method mean. number of higher in normal : 0. number of higher in False : 0. total 0',)
# /Users/priya/Desktop/heatsequer/heatsequer/utils/amnonutils.py:323: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   new_pvalues = np.empty(n)
