# %%
# %matplotlib notebook
import sys
sys.path.append('/Users/priya/Desktop/heatsequer')
import heatsequer as hs
import csv
import numpy as np

# %%
mm=hs.load('../data/otu_100nt_235samples.biom', '../data/ag235_w_scores_alpha.txt')
# Out:
# ('Loading biom table ../data/otu_100nt_235samples.biom',)
# 29ddb45b32fd2263221711e067bb7f04
# ('Loading mapping file ../data/ag235_w_scores_alpha.txt',)
# ('number of samples in map is 235',)
# ('number of samples in table is 235',)
# ('removing 0 samples',)
# ('deleted. number of samples in table is now 235',)
# ('number of samples in mapping file is now 235',)

# %%
#sort by age
mm=hs.sortsamples(mm,'bin_bdi21_score',numeric=True)

# %%
mmc=hs.clusterbacteria(mm,10)
# Out:
# ('2043 Bacteria left',)

# %%
#getting differentially abundant bacteria
dd=hs.getdiffsig(mm,'bin_bdi21_score','1','4','ranksum')
# Out:
# ('188 Samples left',)
# ('17 Samples left',)
# /Users/priya/Desktop/heatsequer/heatsequer/utils/amnonutils.py:323: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   new_pvalues = np.empty(n)
# ('method ranksum. number of higher in 1 : 0. number of higher in 4 : 0. total 0',)

# %%
dd=hs.getpfdr(mm,'bin_bdi21_score','1','4','ranksum',maxfval=0.25)
# Out:
# ('188 Samples left',)
# ('17 Samples left',)
# (27912, 205)
# permuting
# ok
# float64
# float64
# calculating fdr
# fixing floating point errors
# rank transforming
# fdring
# ok
# number of rejects : 75
# ('method ranksum. number of higher in 1 : 63. number of higher in 4 : 12. total 75',)

# %%
ddc=hs.clusterbacteria(dd, 10)
ddc=hs.filtersamples(ddc, 'bin_bdi21_score', ['1','4'])
hs.plotexp(ddc,'bin_bdi21_score')
# Out:
# ('75 Bacteria left',)
# ('205 Samples left',)
# ('75 Bacteria left',)
# <img src="data:image/png;base64,...">
# /Users/priya/anaconda2/envs/heatsequer/lib/python3.5/site-packages/matplotlib/artist.py:221: MatplotlibDeprecationWarning: This has been deprecated in mpl 1.5, please use the
# axes property.  A removal date has not been set.
#   warnings.warn(_get_axes_msg, mplDeprecation, stacklevel=1)
# (<heatsequer.experiment.expclass.Experiment at 0x12b210ac8>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1309bf4a8>)

# %% [markdown]
# # Just look at extremes

# %%
mmb=hs.load('../data/otu_100nt_235samples.biom','../data/ag34_w_scores_alpha_extremes.txt')
# Out:
# ('Loading biom table ../data/otu_100nt_235samples.biom',)
# 29ddb45b32fd2263221711e067bb7f04
# ('Loading mapping file ../data/ag34_w_scores_alpha_extremes.txt',)
# ('number of samples in map is 34',)
# ('number of samples in table is 235',)
# ('Table sample 10317.000030760 not found in mapping file',)
# ('Table sample 10317.000030732 not found in mapping file',)
# ('Table sample 10317.000023384 not found in mapping file',)
# ('Table sample 10317.000026137 not found in mapping file',)
# ('Table sample 10317.000030734 not found in mapping file',)
# ('Table sample 10317.000017085 not found in mapping file',)
# ('Table sample 10317.000036391 not found in mapping file',)
# ('Table sample 10317.000036087 not found in mapping file',)
# ('Table sample 10317.000017072 not found in mapping file',)
# ('Table sample 10317.000030735 not found in mapping file',)
# ('Table sample 10317.000017083 not found in mapping file',)
# ('Table sample 10317.000036383 not found in mapping file',)
# ...

# %%
mmbc=hs.clusterbacteria(mmb,10)
# Out:
# ('909 Bacteria left',)

# %%
hs.plotexp(mmbc,'bin_bdi21_score')
# Out:
# ('909 Bacteria left',)
# <img src="data:image/png;base64,...">
# /Users/priya/anaconda2/envs/heatsequer/lib/python3.5/site-packages/matplotlib/artist.py:221: MatplotlibDeprecationWarning: This has been deprecated in mpl 1.5, please use the
# axes property.  A removal date has not been set.
#   warnings.warn(_get_axes_msg, mplDeprecation, stacklevel=1)
# (<heatsequer.experiment.expclass.Experiment at 0x123af3160>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x123af3eb8>)

# %%
dd=hs.getdiffsig(mmbc,'depression_level', 'normal')
# Out:
# ('16 Samples left',)
# ('16 Samples left',)
# ('method mean. number of higher in normal : 0. number of higher in False : 0. total 0',)
# /Users/priya/Desktop/heatsequer/heatsequer/utils/amnonutils.py:323: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   new_pvalues = np.empty(n)

# %%
dd=hs.getpfdr(mmbc,'bin_bdi21_score','1','4','ranksum',maxfval=0.25)
# Out:
# ('17 Samples left',)
# ('17 Samples left',)
# (909, 34)
# permuting
# ok
# float64
# float64
# calculating fdr
# fixing floating point errors
# rank transforming
# fdring
# ok
# number of rejects : 2
# ('method ranksum. number of higher in 1 : 0. number of higher in 4 : 2. total 2',)

# %%
hs.plotexp(dd,'bin_bdi21_score')
# Out:
# ('2 Bacteria left',)
# <img src="data:image/png;base64,...">
# /Users/priya/anaconda2/envs/heatsequer/lib/python3.5/site-packages/matplotlib/artist.py:221: MatplotlibDeprecationWarning: This has been deprecated in mpl 1.5, please use the
# axes property.  A removal date has not been set.
#   warnings.warn(_get_axes_msg, mplDeprecation, stacklevel=1)
# (<heatsequer.experiment.expclass.Experiment at 0x123a62d68>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x126637a90>)
